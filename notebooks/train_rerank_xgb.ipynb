# %% [markdown]
# # Train Smart-Search XGBRanker
#
# This notebook trains an offline LambdaRank model using 30-day parquet features and exports `models/search_rerank.json`.

# %%
from analytics.train_rerank import train

# %%
metrics = train(
    days=30,
    output="models/search_rerank.json",
    features_prefix="s3://propnexus-ml/features",
)
metrics

# %% [markdown]
# ## Notes
# - Model objective: `rank:ndcg`
# - CLI equivalent: `python analytics/train_rerank.py --days 30 --output models/search_rerank.json`
